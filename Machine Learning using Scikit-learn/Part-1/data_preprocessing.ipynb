# %% [markdown]
# **Let's Start Machine Learning**

# %%
import pandas as pd

data = {
    'Name' : ['Karan', 'Raj', 'Kanishk', 'Naman'],
    'Age' : [16, None, 20, 22],
    'Salary' : [10000, None, 30000, None]
}

df = pd.DataFrame(data)
print("Original Data")
print(df)
print(df.isnull().sum())

print(df.isnull().mean()*100)

df_drop = df.dropna()
print(df_drop)
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
print(df)
# Out:
# Original Data
#       Name   Age   Salary
# 0    Karan  16.0  10000.0
# 1      Raj   NaN      NaN
# 2  Kanishk  20.0  30000.0
# 3    Naman  22.0      NaN
# Name      0
# Age       1
# Salary    2
# dtype: int64
# Name       0.0
# Age       25.0
# Salary    50.0
# dtype: float64
#       Name   Age   Salary
# 0    Karan  16.0  10000.0
# 2  Kanishk  20.0  30000.0
#       Name        Age   Salary
# 0    Karan  16.000000  10000.0
# 1      Raj  19.333333  20000.0
# 2  Kanishk  20.000000  30000.0
# 3    Naman  22.000000  20000.0

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

df = pd.read_csv("data.csv")

df_label = df.copy()
le = LabelEncoder()
df_label['Gender_Encoded'] = le.fit_transform(df_label['Gender'])
df_label['Passed_Encoded'] = le.fit_transform(df_label['Passed'])

print("\nLabeled Encoded Data")
print(df_label[['Name', 'Gender', 'Gender_Encoded', 'Passed', 'Passed_Encoded']])
df_encoded = pd.get_dummies(df_label, columns=['City'])
print('\nOne hot encoded (City)')
print(df_encoded)
# Out:
# Labeled Encoded Data
#       Name  Gender  Gender_Encoded Passed  Passed_Encoded
# 0     Aman    Male               1    Yes               2
# 1    Priya  Female               0    Yes               2
# 2    Rahul    Male               1     No               1
# 3   Anjali  Female               0    Yes               2
# 4     Ravi    Male               1    Yes               2
# 5    Meera  Female               0     No               1
# 6    Arjun    Male               1    Yes               2
# 7     Neha  Female               0    Yes               2
# 8    Imran    Male               1     No               1
# 9    Sneha  Female               0    Yes               2
# 10     Raj    Male               1    Yes               2
# 11   Divya  Female               0     No               1
# 12   Kabir    Male               1    Yes               2
# 13  Simran  Female               0    Yes               2
# 14   Karan    Male               1     No               1
# 15   Pooja  Female               0    Yes               2
# 16  Rakesh    Male               1    Yes               2
# 17    Isha  Female               0     No               0
# 18   Rohit    Male               1    Yes               2
# 19   Deepa  Female               0    Yes               2
#
# One hot encoded (City)
#       Name  Gender Passed  ...  City_Chennai  City_Delhi  City_Mumbai
# 0     Aman    Male    Yes  ...         False       False        False
# 1    Priya  Female    Yes  ...         False       False         True
# 2    Rahul    Male     No  ...         False       False        False
# 3   Anjali  Female    Yes  ...         False       False         True
# 4     Ravi    Male    Yes  ...         False       False        False
# 5    Meera  Female     No  ...          True       False        False
# 6    Arjun    Male    Yes  ...         False       False        False
# 7     Neha  Female    Yes  ...         False        True        False
# 8    Imran    Male     No  ...         False       False        False
# 9    Sneha  Female    Yes  ...         False       False         True
# 10     Raj    Male    Yes  ...         False       False        False
# 11   Divya  Female     No  ...         False        True        False
# 12   Kabir    Male    Yes  ...         False       False        False
# 13  Simran  Female    Yes  ...         False       False        False
# 14   Karan    Male     No  ...         False       False        False
# 15   Pooja  Female    Yes  ...         False       False         True
# 16  Rakesh    Male    Yes  ...         False       False        False
# 17    Isha  Female     No  ...         False        True        False
# 18   Rohit    Male    Yes  ...         False       False        False
# 19   Deepa  Female    Yes  ...         False       False        False
#
# [20 rows x 13 columns]

# %%
from sklearn.preprocessing import StandardScaler, minmax_scale

scaler = StandardScaler()
X_scaled = scaler.fit_transform()

scaler = minmax_scale()
X_scaled = scaler.fit_transform()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 from sklearn.preprocessing import StandardScaler, minmax_scale
#       3 scaler = StandardScaler()
# ----> 4 X_scaled = scaler.fit_transform()
#       6 scaler = minmax_scale()
#       7 X_scaled = scaler.fit_transform()
#
# TypeError: TransformerMixin.fit_transform() missing 1 required positional argument: 'X'

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd
from sklearn.model_selection import train_test_split

data = {
    'StudyHours':[1,2,3,4,5],
    'TestScore':[40,50,60,70,80]
}

df = pd.DataFrame(data)

Standard_Scaler = StandardScaler()
Standard_Scaled = Standard_Scaler.fit_transform(df)

print("Standsrd Scaler Outut:")
print(pd.DataFrame(Standard_Scaled, columns=['StudyHours', 'TestScore']))

minmax_scaler = MinMaxScaler()
minmax_scaled = minmax_scaler.fit_transform(df)

print("Minmax Scaler Outut:\n")
print(pd.DataFrame(minmax_scaled, columns=['StudyHours', 'TestScore']))

x = df[['StudyHours']]
y = df[['TestScore']]

x_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print('Trainng Data')
print(x_train)

print('Test Data')
print(X_test)



print('Trainng Data')
print(y_train)

print('Test Data')
print(y_test)
# Out:
# Standsrd Scaler Outut:
#    StudyHours  TestScore
# 0   -1.414214  -1.414214
# 1   -0.707107  -0.707107
# 2    0.000000   0.000000
# 3    0.707107   0.707107
# 4    1.414214   1.414214
# Minmax Scaler Outut:
#
#    StudyHours  TestScore
# 0        0.00       0.00
# 1        0.25       0.25
# 2        0.50       0.50
# 3        0.75       0.75
# 4        1.00       1.00
# Trainng Data
#    StudyHours
# 4           5
# 2           3
# 0           1
# 3           4
# Test Data
#    StudyHours
# 1           2
# Trainng Data
#    TestScore
# 4         80
# 2         60
# 0         40
# 3         70
# Test Data
#    TestScore
# 1         50
